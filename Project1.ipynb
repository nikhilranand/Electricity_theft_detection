# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Create Dataframe and Read the dataset using Pandas
dataset = pd.read_csv('meter1.csv')
dataset.head()
# Out:
#    0  Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0  0                          22.035977                       3.586221
# 1  1                          14.649757                       0.000000
# 2  2                          14.669567                       0.000000
# 3  3                          14.677808                       0.000000
# 4  4                          14.824794                       0.000000
#
#    Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                               0.0                                 0
# 1                               0.0                                 0
# 2                               0.0                                 0
# 3                               0.0                                 0
# 4                               0.0                                 0
#
#    InteriorLights:Electricity [kW](Hourly)  \
# 0                                 4.589925
# ...

# %%
#Convert list into Dataframe
df = pd.DataFrame(dataset)
df
# Out:
#          0  Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0        0                          22.035977                       3.586221
# 1        1                          14.649757                       0.000000
# 2        2                          14.669567                       0.000000
# 3        3                          14.677808                       0.000000
# 4        4                          14.824794                       0.000000
# ...    ...                                ...                            ...
# 8755  8755                          38.216539                       3.586221
# 8756  8756                          38.199381                       3.586221
# 8757  8757                          38.129123                       3.586221
# 8758  8758                          38.017393                       3.586221
# 8759  8759                          38.825801                       3.586221
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   0                                           8760 non-null   int64
#  1   Electricity:Facility [kW](Hourly)           8760 non-null   float64
#  2   Fans:Electricity [kW](Hourly)               8760 non-null   float64
#  3   Cooling:Electricity [kW](Hourly)            8760 non-null   float64
#  4   Heating:Electricity [kW](Hourly)            8760 non-null   int64
#  5   InteriorLights:Electricity [kW](Hourly)     8760 non-null   float64
#  6   InteriorEquipment:Electricity [kW](Hourly)  8760 non-null   float64
#  7   Gas:Facility [kW](Hourly)                   8760 non-null   float64
#  8   Heating:Gas [kW](Hourly)                    8760 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# 0                                             0
# Electricity:Facility [kW](Hourly)             0
# Fans:Electricity [kW](Hourly)                 0
# Cooling:Electricity [kW](Hourly)              0
# Heating:Electricity [kW](Hourly)              0
# InteriorLights:Electricity [kW](Hourly)       0
# InteriorEquipment:Electricity [kW](Hourly)    0
# Gas:Facility [kW](Hourly)                     0
# Heating:Gas [kW](Hourly)                      0
# InteriorEquipment:Gas [kW](Hourly)            0
# Water Heater:WaterSystems:Gas [kW](Hourly)    0
# Class                                         0
# theft                                         0
# dtype: int64

# %%
df.describe().T
# Out:
#                                              count         mean          std  \
# 0                                           8760.0  4379.500000  2528.938512
# Electricity:Facility [kW](Hourly)           8760.0    26.513124    13.972055
# Fans:Electricity [kW](Hourly)               8760.0     2.382121     1.488440
# Cooling:Electricity [kW](Hourly)            8760.0     0.032475     0.245539
# Heating:Electricity [kW](Hourly)            8760.0     0.000000     0.000000
# InteriorLights:Electricity [kW](Hourly)     8760.0     5.986867     3.507823
# InteriorEquipment:Electricity [kW](Hourly)  8760.0    15.050536     8.717209
# Gas:Facility [kW](Hourly)                   8760.0    66.364617    52.580942
# Heating:Gas [kW](Hourly)                    8760.0    37.288672    40.930028
# InteriorEquipment:Gas [kW](Hourly)          8760.0    20.166686    15.540550
# Water Heater:WaterSystems:Gas [kW](Hourly)  8760.0     8.909259     6.809317
#
# ...

# %%
# Check Unique values of target variable
df.theft.value_counts()
# Out:
# Normal    5101
# Theft1     811
# Theft4     662
# Theft3     659
# Theft6     564
# Theft5     515
# Theft2     448
# Name: theft, dtype: int64

# %%
#Droping class feature 
df1 = df.drop(['0','Class'], axis=1)
df1
# Out:
#       Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0                             22.035977                       3.586221
# 1                             14.649757                       0.000000
# 2                             14.669567                       0.000000
# 3                             14.677808                       0.000000
# 4                             14.824794                       0.000000
# ...                                 ...                            ...
# 8755                          38.216539                       3.586221
# 8756                          38.199381                       3.586221
# 8757                          38.129123                       3.586221
# 8758                          38.017393                       3.586221
# 8759                          38.825801                       3.586221
#
#       Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# ...

# %%
df1
# Out:
#       Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0                             22.035977                       3.586221
# 1                             14.649757                       0.000000
# 2                             14.669567                       0.000000
# 3                             14.677808                       0.000000
# 4                             14.824794                       0.000000
# ...                                 ...                            ...
# 8755                          38.216539                       3.586221
# 8756                          38.199381                       3.586221
# 8757                          38.129123                       3.586221
# 8758                          38.017393                       3.586221
# 8759                          38.825801                       3.586221
#
#       Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming you have a DataFrame 'df1' with a 'class_label' column
# Replace 'class_label' with the actual name of your class label column

theft = ["Normal", "Theft1","Theft2","Theft3","Theft4","Theft5","Theft6"]

# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit the label encoder to your class labels
label_encoder.fit(theft)

# Transform the class labels in your DataFrame
df1['theft_encoded'] = label_encoder.transform(df1['theft'])

# %%
# Check counts
df1.theft.value_counts()
# Out:
# Normal    5101
# Theft1     811
# Theft4     662
# Theft3     659
# Theft6     564
# Theft5     515
# Theft2     448
# Name: theft, dtype: int64

# %%
# Check counts
df1.theft_encoded.value_counts()
# Out:
# 0    5101
# 1     811
# 4     662
# 3     659
# 6     564
# 5     515
# 2     448
# Name: theft_encoded, dtype: int64

# %%
df1
# Out:
#       Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0                             22.035977                       3.586221
# 1                             14.649757                       0.000000
# 2                             14.669567                       0.000000
# 3                             14.677808                       0.000000
# 4                             14.824794                       0.000000
# ...                                 ...                            ...
# 8755                          38.216539                       3.586221
# 8756                          38.199381                       3.586221
# 8757                          38.129123                       3.586221
# 8758                          38.017393                       3.586221
# 8759                          38.825801                       3.586221
#
#       Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# ...

# %% [markdown]
# ## Visualization of Distribution

# %%
# Percentage for PieChart
percentage = df.theft.value_counts(normalize=True)*100
percentage
# Out:
# Normal    58.230594
# Theft1     9.257991
# Theft4     7.557078
# Theft3     7.522831
# Theft6     6.438356
# Theft5     5.878995
# Theft2     5.114155
# Name: theft, dtype: float64

# %%
#plotting PieChart
Theftlabels = ["NORMAL", "THEFT1","THEFT2","THEFT3","THEFT4","THEFT5","THEFT6"]
plt.figure(figsize =(12, 7))
plt.pie(percentage,labels = Theftlabels,autopct='%1.1f%%')  
plt.title ("Pie Chart of theft", fontsize = 15)
plt.show()
