# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Create Dataframe and Read the dataset using Pandas
dataset = pd.read_csv('meter1.csv')
dataset.head()
# Out:
#    0  Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0  0                          22.035977                       3.586221
# 1  1                          14.649757                       0.000000
# 2  2                          14.669567                       0.000000
# 3  3                          14.677808                       0.000000
# 4  4                          14.824794                       0.000000
#
#    Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                               0.0                                 0
# 1                               0.0                                 0
# 2                               0.0                                 0
# 3                               0.0                                 0
# 4                               0.0                                 0
#
#    InteriorLights:Electricity [kW](Hourly)  \
# 0                                 4.589925
# 1                                 1.529975
# 2                                 1.529975
# 3                                 1.529975
# 4                                 1.529975
#
#    InteriorEquipment:Electricity [kW](Hourly)  Gas:Facility [kW](Hourly)  \
# 0                                      8.1892                 136.585903
# 1                                      7.4902                   3.359880
# 2                                      7.4902                   3.359880
# 3                                      7.4902                   3.931932
# 4                                      7.4902                   3.359880
#
#    Heating:Gas [kW](Hourly)  InteriorEquipment:Gas [kW](Hourly)  \
# 0                123.999076                             3.33988
# 1                  0.000000                             3.33988
# 2                  0.000000                             3.33988
# 3                  0.000000                             3.33988
# 4                  0.000000                             3.33988
#
#    Water Heater:WaterSystems:Gas [kW](Hourly)                  Class   theft
# 0                                    9.246947  FullServiceRestaurant  Normal
# 1                                    0.020000  FullServiceRestaurant  Normal
# 2                                    0.020000  FullServiceRestaurant  Normal
# 3                                    0.592052  FullServiceRestaurant  Normal
# 4                                    0.020000  FullServiceRestaurant  Normal

# %%
#Convert list into Dataframe
df = pd.DataFrame(dataset)
df
# Out:
#          0  Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0        0                          22.035977                       3.586221
# 1        1                          14.649757                       0.000000
# 2        2                          14.669567                       0.000000
# 3        3                          14.677808                       0.000000
# 4        4                          14.824794                       0.000000
# ...    ...                                ...                            ...
# 8755  8755                          38.216539                       3.586221
# 8756  8756                          38.199381                       3.586221
# 8757  8757                          38.129123                       3.586221
# 8758  8758                          38.017393                       3.586221
# 8759  8759                          38.825801                       3.586221
#
#       Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                                  0.0                                 0
# 1                                  0.0                                 0
# 2                                  0.0                                 0
# 3                                  0.0                                 0
# 4                                  0.0                                 0
# ...                                ...                               ...
# 8755                               0.0                                 0
# 8756                               0.0                                 0
# 8757                               0.0                                 0
# 8758                               0.0                                 0
# 8759                               0.0                                 0
#
#       InteriorLights:Electricity [kW](Hourly)  \
# 0                                    4.589925
# 1                                    1.529975
# 2                                    1.529975
# 3                                    1.529975
# 4                                    1.529975
# ...                                       ...
# 8755                                 9.179851
# 8756                                 9.179851
# 8757                                 9.179851
# 8758                                 9.179851
# 8759                                 9.179851
#
#       InteriorEquipment:Electricity [kW](Hourly)  Gas:Facility [kW](Hourly)  \
# 0                                         8.1892                 136.585903
# 1                                         7.4902                   3.359880
# 2                                         7.4902                   3.359880
# 3                                         7.4902                   3.931932
# 4                                         7.4902                   3.359880
# ...                                          ...                        ...
# 8755                                     19.4245                 137.418074
# 8756                                     19.4245                 130.424326
# 8757                                     19.4245                 134.117636
# 8758                                     19.4245                 125.885592
# 8759                                     19.4245                 107.861805
#
#       Heating:Gas [kW](Hourly)  InteriorEquipment:Gas [kW](Hourly)  \
# 0                   123.999076                             3.33988
# 1                     0.000000                             3.33988
# 2                     0.000000                             3.33988
# 3                     0.000000                             3.33988
# 4                     0.000000                             3.33988
# ...                        ...                                 ...
# 8755                 85.963982                            33.39880
# 8756                 82.510920                            33.39880
# 8757                 90.431849                            25.04910
# 8758                 94.674521                            16.69940
# 8759                 92.005940                             8.34970
#
#       Water Heater:WaterSystems:Gas [kW](Hourly)                  Class  \
# 0                                       9.246947  FullServiceRestaurant
# 1                                       0.020000  FullServiceRestaurant
# 2                                       0.020000  FullServiceRestaurant
# 3                                       0.592052  FullServiceRestaurant
# 4                                       0.020000  FullServiceRestaurant
# ...                                          ...                    ...
# 8755                                   18.055292  FullServiceRestaurant
# 8756                                   14.514605  FullServiceRestaurant
# 8757                                   18.636687  FullServiceRestaurant
# 8758                                   14.511671  FullServiceRestaurant
# 8759                                    7.506165  FullServiceRestaurant
#
#        theft
# 0     Normal
# 1     Normal
# 2     Normal
# 3     Normal
# 4     Normal
# ...      ...
# 8755  Normal
# 8756  Normal
# 8757  Normal
# 8758  Normal
# 8759  Normal
#
# [8760 rows x 13 columns]

# %%
#Droping class feature 
df1 = df.drop(['0','Class'], axis=1)
df1
# Out:
#       Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0                             22.035977                       3.586221
# 1                             14.649757                       0.000000
# 2                             14.669567                       0.000000
# 3                             14.677808                       0.000000
# 4                             14.824794                       0.000000
# ...                                 ...                            ...
# 8755                          38.216539                       3.586221
# 8756                          38.199381                       3.586221
# 8757                          38.129123                       3.586221
# 8758                          38.017393                       3.586221
# 8759                          38.825801                       3.586221
#
#       Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                                  0.0                                 0
# 1                                  0.0                                 0
# 2                                  0.0                                 0
# 3                                  0.0                                 0
# 4                                  0.0                                 0
# ...                                ...                               ...
# 8755                               0.0                                 0
# 8756                               0.0                                 0
# 8757                               0.0                                 0
# 8758                               0.0                                 0
# 8759                               0.0                                 0
#
#       InteriorLights:Electricity [kW](Hourly)  \
# 0                                    4.589925
# 1                                    1.529975
# 2                                    1.529975
# 3                                    1.529975
# 4                                    1.529975
# ...                                       ...
# 8755                                 9.179851
# 8756                                 9.179851
# 8757                                 9.179851
# 8758                                 9.179851
# 8759                                 9.179851
#
#       InteriorEquipment:Electricity [kW](Hourly)  Gas:Facility [kW](Hourly)  \
# 0                                         8.1892                 136.585903
# 1                                         7.4902                   3.359880
# 2                                         7.4902                   3.359880
# 3                                         7.4902                   3.931932
# 4                                         7.4902                   3.359880
# ...                                          ...                        ...
# 8755                                     19.4245                 137.418074
# 8756                                     19.4245                 130.424326
# 8757                                     19.4245                 134.117636
# 8758                                     19.4245                 125.885592
# 8759                                     19.4245                 107.861805
#
#       Heating:Gas [kW](Hourly)  InteriorEquipment:Gas [kW](Hourly)  \
# 0                   123.999076                             3.33988
# 1                     0.000000                             3.33988
# 2                     0.000000                             3.33988
# 3                     0.000000                             3.33988
# 4                     0.000000                             3.33988
# ...                        ...                                 ...
# 8755                 85.963982                            33.39880
# 8756                 82.510920                            33.39880
# 8757                 90.431849                            25.04910
# 8758                 94.674521                            16.69940
# 8759                 92.005940                             8.34970
#
#       Water Heater:WaterSystems:Gas [kW](Hourly)   theft
# 0                                       9.246947  Normal
# 1                                       0.020000  Normal
# 2                                       0.020000  Normal
# 3                                       0.592052  Normal
# 4                                       0.020000  Normal
# ...                                          ...     ...
# 8755                                   18.055292  Normal
# 8756                                   14.514605  Normal
# 8757                                   18.636687  Normal
# 8758                                   14.511671  Normal
# 8759                                    7.506165  Normal
#
# [8760 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming you have a DataFrame 'df1' with a 'class_label' column
# Replace 'class_label' with the actual name of your class label column

theft = ["Normal", "Theft1","Theft2","Theft3","Theft4","Theft5","Theft6"]

# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit the label encoder to your class labels
label_encoder.fit(theft)

# Transform the class labels in your DataFrame
df1['theft_encoded'] = label_encoder.transform(df1['theft'])

# %%
df1.theft_encoded.unique()
# Out:
# array([0, 5, 6, 2, 3, 4, 1])

# %%
df1
# Out:
#       Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0                             22.035977                       3.586221
# 1                             14.649757                       0.000000
# 2                             14.669567                       0.000000
# 3                             14.677808                       0.000000
# 4                             14.824794                       0.000000
# ...                                 ...                            ...
# 8755                          38.216539                       3.586221
# 8756                          38.199381                       3.586221
# 8757                          38.129123                       3.586221
# 8758                          38.017393                       3.586221
# 8759                          38.825801                       3.586221
#
#       Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                                  0.0                                 0
# 1                                  0.0                                 0
# 2                                  0.0                                 0
# 3                                  0.0                                 0
# 4                                  0.0                                 0
# ...                                ...                               ...
# 8755                               0.0                                 0
# 8756                               0.0                                 0
# 8757                               0.0                                 0
# 8758                               0.0                                 0
# 8759                               0.0                                 0
#
#       InteriorLights:Electricity [kW](Hourly)  \
# 0                                    4.589925
# 1                                    1.529975
# 2                                    1.529975
# 3                                    1.529975
# 4                                    1.529975
# ...                                       ...
# 8755                                 9.179851
# 8756                                 9.179851
# 8757                                 9.179851
# 8758                                 9.179851
# 8759                                 9.179851
#
#       InteriorEquipment:Electricity [kW](Hourly)  Gas:Facility [kW](Hourly)  \
# 0                                         8.1892                 136.585903
# 1                                         7.4902                   3.359880
# 2                                         7.4902                   3.359880
# 3                                         7.4902                   3.931932
# 4                                         7.4902                   3.359880
# ...                                          ...                        ...
# 8755                                     19.4245                 137.418074
# 8756                                     19.4245                 130.424326
# 8757                                     19.4245                 134.117636
# 8758                                     19.4245                 125.885592
# 8759                                     19.4245                 107.861805
#
#       Heating:Gas [kW](Hourly)  InteriorEquipment:Gas [kW](Hourly)  \
# 0                   123.999076                             3.33988
# 1                     0.000000                             3.33988
# 2                     0.000000                             3.33988
# 3                     0.000000                             3.33988
# 4                     0.000000                             3.33988
# ...                        ...                                 ...
# 8755                 85.963982                            33.39880
# 8756                 82.510920                            33.39880
# 8757                 90.431849                            25.04910
# 8758                 94.674521                            16.69940
# 8759                 92.005940                             8.34970
#
#       Water Heater:WaterSystems:Gas [kW](Hourly)   theft  theft_encoded
# 0                                       9.246947  Normal              0
# 1                                       0.020000  Normal              0
# 2                                       0.020000  Normal              0
# 3                                       0.592052  Normal              0
# 4                                       0.020000  Normal              0
# ...                                          ...     ...            ...
# 8755                                   18.055292  Normal              0
# 8756                                   14.514605  Normal              0
# 8757                                   18.636687  Normal              0
# 8758                                   14.511671  Normal              0
# 8759                                    7.506165  Normal              0
#
# [8760 rows x 12 columns]

# %%
## independent and dependent feature
X=df1.drop(labels=['theft','theft_encoded'],axis=1)
y=df1.theft_encoded

# %%
X.head()
# Out:
#    Electricity:Facility [kW](Hourly)  Fans:Electricity [kW](Hourly)  \
# 0                          22.035977                       3.586221
# 1                          14.649757                       0.000000
# 2                          14.669567                       0.000000
# 3                          14.677808                       0.000000
# 4                          14.824794                       0.000000
#
#    Cooling:Electricity [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                               0.0                                 0
# 1                               0.0                                 0
# 2                               0.0                                 0
# 3                               0.0                                 0
# 4                               0.0                                 0
#
#    InteriorLights:Electricity [kW](Hourly)  \
# 0                                 4.589925
# 1                                 1.529975
# 2                                 1.529975
# 3                                 1.529975
# 4                                 1.529975
#
#    InteriorEquipment:Electricity [kW](Hourly)  Gas:Facility [kW](Hourly)  \
# 0                                      8.1892                 136.585903
# 1                                      7.4902                   3.359880
# 2                                      7.4902                   3.359880
# 3                                      7.4902                   3.931932
# 4                                      7.4902                   3.359880
#
#    Heating:Gas [kW](Hourly)  InteriorEquipment:Gas [kW](Hourly)  \
# 0                123.999076                             3.33988
# 1                  0.000000                             3.33988
# 2                  0.000000                             3.33988
# 3                  0.000000                             3.33988
# 4                  0.000000                             3.33988
#
#    Water Heater:WaterSystems:Gas [kW](Hourly)
# 0                                    9.246947
# 1                                    0.020000
# 2                                    0.020000
# 3                                    0.592052
# 4                                    0.020000

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: theft_encoded, dtype: int32

# %%
### train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
## Hypeparameter Tuning
params={'max_depth':[3,5,10,None],
              'n_estimators':[100,200,300],
               'criterion':['gini','entropy']
              }

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classfier=RandomForestClassifier()

# %%
cv=RandomizedSearchCV(classfier,param_distributions=params,scoring='accuracy',cv=5,verbose=3)
cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.843 total time=   9.6s
# [CV 2/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.859 total time=   8.6s
# [CV 3/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.856 total time=  10.4s
# [CV 4/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.856 total time=  10.5s
# [CV 5/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.858 total time=   9.0s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.857 total time=   5.6s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.882 total time=   5.6s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.876 total time=   5.5s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.871 total time=   6.2s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.874 total time=   5.4s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.832 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.836 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.811 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.825 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.839 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.843 total time=   3.5s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.854 total time=   3.7s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.853 total time=   3.3s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.851 total time=   3.4s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.857 total time=   3.2s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.818 total time=   1.9s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.815 total time=   1.9s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.822 total time=   1.5s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.825 total time=   1.4s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.823 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.820 total time=   2.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.828 total time=   2.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.822 total time=   2.2s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.828 total time=   2.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.811 total time=   2.4s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.807 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.819 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.810 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.824 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.818 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.850 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.852 total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.849 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.851 total time=   1.3s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.856 total time=   1.5s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.860 total time=   2.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.880 total time=   2.2s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.874 total time=   2.0s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.875 total time=   1.8s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.874 total time=   1.8s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.828 total time=   3.0s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.829 total time=   3.0s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.825 total time=   3.7s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.825 total time=   3.4s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.835 total time=   3.7s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 10, None],
#                                         'n_estimators': [100, 200, 300]},
#                    scoring='accuracy', verbose=3)

# %%
cv.best_params_
# Out:
# {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini'}

# %%
## prediction
y_pred=cv.predict(X_test)

# %%
score=accuracy_score(y_pred,y_test)

# %%
score=accuracy_score(y_pred,y_test)
print(score)
print(classification_report(y_pred,y_test))
# Out:
# 0.8785887236250433
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      1744
#            1       0.76      0.65      0.70       332
#            2       1.00      1.00      1.00       131
#            3       0.62      0.64      0.63       209
#            4       0.98      0.82      0.89       254
#            5       0.97      0.93      0.95       204
#            6       0.01      0.06      0.01        17
#
#     accuracy                           0.88      2891
#    macro avg       0.76      0.72      0.74      2891
# weighted avg       0.93      0.88      0.91      2891

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming y_test and y_pred are lists or arrays
# You can convert them to a DataFrame or Series for easier manipulation

y_test_df = pd.DataFrame(y_test)
y_pred_df = pd.DataFrame(y_pred)

# Assuming df['target'] and df['pred'] are categorical variables with encoded categories 'normal', 'theft1', ..., 'theft6'

# Convert the categories to integer codes
#df['target_num'] = df['target'].cat.codes
#df['pred_num'] = df['pred'].cat.codes

# Use these integer codes to create the confusion matrix
cm = confusion_matrix(y_test_df['theft_encoded'], y_pred_df[0])

# Create a heatmap using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Oranges", xticklabels=["Normal", "Theft1", "Theft2", "Theft3", "Theft4", "Theft5", "Theft6"],
            yticklabels=["Normal", "Theft1", "Theft2", "Theft3", "Theft4", "Theft5", "Theft6"])

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
y_test
# Out:
#       theft_encoded
# 6056              0
# 5556              0
# 5990              0
# 7674              1
# 3319              5
# ...             ...
# 6504              0
# 7210              0
# 4690              0
# 7274              0
# 1170              1
#
# [2891 rows x 1 columns]

# %%
y_pred_df
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     6
# 4     5
# ...  ..
# 2886  0
# 2887  0
# 2888  0
# 2889  0
# 2890  1
#
# [2891 rows x 1 columns]
